# %% [markdown]
# <b> Get Geospatial Coordinates of canada from csv file </b>

# %%
import numpy as np
import pandas as pd

df_geocode = pd.read_csv('Geospatial_Coordinates.csv')
df_postcode = pd.read_csv('canada_postcode.csv')

# %%
df_postcode.shape
# Out:
# (103, 4)

# %% [markdown]
# Print the shape of newly created Dataframe

# %% [markdown]
# geo location and addresses are read from csv files into dataframe
# Addresses which were edited in previous notebook were stored by me to read in this notebook

# %% [markdown]
# Print the shape of geocode dataframe which contains geo location of all postcodes

# %%
df_geocode.shape
# Out:
# (103, 3)

# %%
df_postcode.head(10)
# Out:
#    Unnamed: 0 Postcode      Borough  \
# 0           1      M1B  Scarborough
# 1           2      M1C  Scarborough
# 2           3      M1E  Scarborough
# 3           4      M1G  Scarborough
# 4           5      M1H  Scarborough
# 5           6      M1J  Scarborough
# 6           7      M1K  Scarborough
# 7           8      M1L  Scarborough
# 8           9      M1M  Scarborough
# 9          10      M1N  Scarborough
#
#                                      Neighbourhood
# 0                                   Rouge, Malvern
# 1           Highland Creek, Rouge Hill, Port Union
# 2                Guildwood, Morningside, West Hill
# 3                                           Woburn
# 4                                        Cedarbrae
# 5                              Scarborough Village
# 6      East Birchmount Park, Ionview, Kennedy Park
# 7                  Clairlea, Golden Mile, Oakridge
# 8  Cliffcrest, Cliffside, Scarborough Village West
# ...

# %%
df_geocode.head(10)
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476
# 5         M1J  43.744734 -79.239476
# 6         M1K  43.727929 -79.262029
# 7         M1L  43.711112 -79.284577
# 8         M1M  43.716316 -79.239476
# 9         M1N  43.692657 -79.264848

# %%
df_Spatial=df_postcode

# %% [markdown]
# Create a new dataframe with postcode,address and their corresponding geo location

# %%
df_Spatial['Latitue']=df_geocode['Latitude']
df_Spatial['Longitude']=df_geocode['Longitude']

# %%
df_Spatial.head(10)
# Out:
#    Unnamed: 0 Postcode      Borough  \
# 0           1      M1B  Scarborough
# 1           2      M1C  Scarborough
# 2           3      M1E  Scarborough
# 3           4      M1G  Scarborough
# 4           5      M1H  Scarborough
# 5           6      M1J  Scarborough
# 6           7      M1K  Scarborough
# 7           8      M1L  Scarborough
# 8           9      M1M  Scarborough
# 9          10      M1N  Scarborough
#
#                                      Neighbourhood    Latitue  Longitude
# 0                                   Rouge, Malvern  43.806686 -79.194353
# 1           Highland Creek, Rouge Hill, Port Union  43.784535 -79.160497
# 2                Guildwood, Morningside, West Hill  43.763573 -79.188711
# 3                                           Woburn  43.770992 -79.216917
# 4                                        Cedarbrae  43.773136 -79.239476
# 5                              Scarborough Village  43.744734 -79.239476
# ...

# %%
df_Spatial.drop(df_Spatial.columns[0], axis=1, inplace=True)

# %% [markdown]
# Delete unnecessary column

# %% [markdown]
# Save the newly edited Post code and Addresses with geolocation in a csv file for further use

# %%
df_Spatial.to_csv('canada_postcodeWithGeo.csv')
df_Spatial.shape
# Out:
# (103, 5)

# %%
df_Spatial.head(20)
# Out:
#         Borough                                      Neighbourhood    Latitue  \
# 0   Scarborough                                     Rouge, Malvern  43.806686
# 1   Scarborough             Highland Creek, Rouge Hill, Port Union  43.784535
# 2   Scarborough                  Guildwood, Morningside, West Hill  43.763573
# 3   Scarborough                                             Woburn  43.770992
# 4   Scarborough                                          Cedarbrae  43.773136
# 5   Scarborough                                Scarborough Village  43.744734
# 6   Scarborough        East Birchmount Park, Ionview, Kennedy Park  43.727929
# 7   Scarborough                    Clairlea, Golden Mile, Oakridge  43.711112
# 8   Scarborough    Cliffcrest, Cliffside, Scarborough Village West  43.716316
# 9   Scarborough                        Birch Cliff, Cliffside West  43.692657
# 10  Scarborough  Dorset Park, Scarborough Town Centre, Wexford ...  43.757410
# ...

# %%
Printing top ten rows of
